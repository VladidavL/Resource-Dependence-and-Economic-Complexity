# %%
import os
os.chdir("C:\\Users\\Vladimir.Grigoryev\\Documents\\Python Scripts\\eci")


import pandas as pd
import numpy as np

# %%
# adding oil (and other liquids) production
path = pd.read_csv("API_NY.GDP.PCAP.CD_DS2_en_csv_v2_10576699.csv", header = 2)
tr = pd.DataFrame(path)
tr.head()
# Out:
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2       Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3      Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4      Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#         1960       1961       1962       1963       1964        1965  ...  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 1  59.777327  59.878153  58.492874  78.782758  82.208444  101.290471  ...
# 2        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 4        NaN        NaN        NaN        NaN        NaN         NaN  ...
#
#            2010          2011          2012          2013          2014  \
# ...

# %%
tr.drop(["Indicator Code", "Indicator Name", "Country Name", "Unnamed: 63"], axis=1, inplace=True)

# %%
tr.tail()
# Out:
#     Country Code        1960        1961        1962        1963        1964  \
# 259          XKX         NaN         NaN         NaN         NaN         NaN
# 260          YEM         NaN         NaN         NaN         NaN         NaN
# 261          ZAF  433.941194  444.896268  461.798232  498.601747  534.374176
# 262          ZMB  234.166194  221.728401  213.894229  214.852954  243.105320
# 263          ZWE  280.994586  283.315869  279.440989  280.566213  285.053174
#
#            1965        1966        1967        1968  ...         2009  \
# 259         NaN         NaN         NaN         NaN  ...  3209.694109
# 260         NaN         NaN         NaN         NaN  ...  1093.812918
# 261  568.348265  603.069811  654.626304  688.830622  ...  5805.998362
# 262  303.882532  343.912055  360.770244  410.486261  ...  1139.110233
# 263  297.363437  281.490800  297.231875  304.982159  ...   699.882264
#
#             2010         2011         2012         2013         2014  \
# ...

# %%
inst = tr.values
inst
# Out:
# array([['ABW', nan, nan, ..., 25251.6396777554, 25655.1020217537, nan],
#        ['AFG', 59.7773265083934, 59.87815280894711, ...,
#         549.582759921642, 550.068458763852, nan],
#        ['AGO', nan, nan, ..., 3509.6042114227303, 4100.28978571722, nan],
#        ...,
#        ['ZAF', 433.941193590145, 444.896268303603, ..., 5279.73047236548,
#         6151.0779553128505, nan],
#        ['ZMB', 234.166194283717, 221.72840063310397, ...,
#         1262.98968188557, 1513.27631610687, nan],
#        ['ZWE', 280.994585801398, 283.315869044703, ...,
#         1272.3354498183999, 1333.3956627939301, nan]], dtype=object)

# %%
data = np.array(["code", "year", "gdp_pc"])
years = np.arange(1960,2019)
for i in range(len(inst)):
    name = inst[i][0]
    country = [name for x in range(len(years))]
    series = inst[i][1:]
    block = np.vstack((country, years, series))
    data = np.vstack((data, block.T))
data
# Out:
# array([['code', 'year', 'gdp_pc'],
#        ['ABW', 1960, nan],
#        ['ABW', 1961, nan],
#        ...,
#        ['ZWE', 2016, 1272.3354498183999],
#        ['ZWE', 2017, 1333.3956627939301],
#        ['ZWE', 2018, nan]], dtype=object)

# %%
er = pd.DataFrame(data)
headers = er.iloc[0]
et  = pd.DataFrame(er.values[1:], columns=headers)
et.head()
# Out:
# 0 code  year gdp_pc
# 0  ABW  1960    NaN
# 1  ABW  1961    NaN
# 2  ABW  1962    NaN
# 3  ABW  1963    NaN
# 4  ABW  1964    NaN

# %%
et["map"] = et.index
inst = et.values

for i in et.index:
    inst[i][3] = str(inst[i][0]) + str(inst[i][1])
    
ei = pd.DataFrame(inst, columns=("code", "year", "gdp_pc", "map"))
ei.head()
# Out:
#   code  year gdp_pc      map
# 0  ABW  1960    NaN  ABW1960
# 1  ABW  1961    NaN  ABW1961
# 2  ABW  1962    NaN  ABW1962
# 3  ABW  1963    NaN  ABW1963
# 4  ABW  1964    NaN  ABW1964

# %%
eo = ei[["map", "gdp_pc"]]

# %%
eo.to_csv("GDP_pc.csv")
