# %%
# Adding resource abundance proxies to the data
# Resource rents
# Oil rents
# Resource exports share in total exports

# %%
# Adding resource rents
import os
os.chdir("C:\\Users\\Vladimir.Grigoryev\\Documents\\Python Scripts\\eci")

# %%
import pandas as pd
import numpy as np

path = pd.read_csv("Resource_rents.csv", sep = ",", header = 2)
r_rents = pd.DataFrame(path)

# %%
r_rents.drop(["Indicator Name", "Indicator Code"], axis = 1, inplace = True)
r_rents.head(5)
# Out:
#   Country Name Country Code  1960  1961  1962  1963  1964  1965  1966  1967  \
# 0        Aruba          ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       Angola          AGO   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      Albania          ALB   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      Andorra          AND   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...       2010       2011       2012       2013       2014       2015  \
# 0  ...   0.002361   0.001948   0.001973   0.002363   0.003402   0.002613
# 1  ...   0.588007   0.841949   0.680631   0.526111   0.495682   0.479033
# 2  ...  39.003947  39.887097  35.678268  30.470816  23.381930  10.803628
# 3  ...   2.033753   3.455044   3.596120   3.578365   3.574897   1.813210
# 4  ...   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         2016       2017  2018  Unnamed: 63
# ...

# %%
codes = r_rents.iloc[:,:2]
codes.head()
# Out:
#   Country Name Country Code
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND

# %%
codes.to_csv("codes.csv")
